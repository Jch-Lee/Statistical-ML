# %%
import numpy as np
import pandas as pd

# Core packages for general use throughout the notebook.

import random
import warnings
import time
import datetime

# For customizing our plots.

from matplotlib.ticker import MaxNLocator
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

# Loading pytorch packages.

import torch
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, BertConfig, get_linear_schedule_with_warmup
from torch.utils.data import TensorDataset, random_split, DataLoader, RandomSampler, SequentialSampler

# %%
# If there's a GPU available...

if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.  
    
    device = torch.device('cuda')    


    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device('cpu')
# Out:
# No GPU available, using the CPU instead.

# %%
# Loading the data for modelling.

train = pd.read_csv('train_cleaned.csv')
test = pd.read_csv('test_cleaned.csv')

print(f'Number of training tweets: {train.shape[0]}\n')
print(f'Number of training tweets: {test.shape[0]}\n')

display(train.sample(4))
# Out:
# Number of training tweets: 7613
#
# Number of training tweets: 3263
#         id               keyword         location  \
# 5931  8471              screamed        18 ??? CC
# 470    680                attack  Halton, Ontario
# 874   1267                 blood    PunPunl??ndia
# 6352  9082  structural%20failure              NaN
#
#                                                    text  target  \
# 5931  Some kids going to leadership camp came into m...       0
# 470   Suspect in latest US theatre attack had psycho...       1
# 874                             @Lobo_paranoico Mad Men       0
# 6352  Slums are a manifestation state failure to pro...       1
#
#                                              text_clean  \
# 5931  Some kids going to leadership camp came into m...
# 470   Suspect in latest US theatre attack had psycho...
# 874                              @Loboparanoico Mad Men
# 6352  Slums are a manifestation state failure to pro...
#
#                                               tokenized  \
# 5931  ['Some', 'kids', 'going', 'to', 'leadership', ...
# 470   ['Suspect', 'in', 'latest', 'US', 'theatre', '...
# 874                    ['@Loboparanoico', 'Mad', 'Men']
# 6352  ['Slums', 'are', 'a', 'manifestation', 'state'...
#
#                                                   lower  \
# 5931  ['some', 'kids', 'going', 'to', 'leadership', ...
# 470   ['suspect', 'in', 'latest', 'us', 'theatre', '...
# 874                    ['@loboparanoico', 'mad', 'men']
# 6352  ['slums', 'are', 'a', 'manifestation', 'state'...
#
#                                       stopwords_removed  \
# 5931  ['kids', 'going', 'leadership', 'camp', 'came'...
# 470   ['suspect', 'latest', 'us', 'theatre', 'attack...
# 874                    ['@loboparanoico', 'mad', 'men']
# 6352  ['slums', 'manifestation', 'state', 'failure',...
#
#                                                pos_tags  \
# 5931  [('kids', 'NNS'), ('going', 'VBG'), ('leadersh...
# 470   [('suspect', 'JJ'), ('latest', 'JJS'), ('us', ...
# 874   [('@loboparanoico', 'JJ'), ('mad', 'NNS'), ('m...
# 6352  [('slums', 'NNS'), ('manifestation', 'NN'), ('...
#
#                                             wordnet_pos  \
# 5931  [('kids', 'n'), ('going', 'v'), ('leadership',...
# 470   [('suspect', 'a'), ('latest', 'a'), ('us', 'n'...
# 874   [('@loboparanoico', 'a'), ('mad', 'n'), ('men'...
# 6352  [('slums', 'n'), ('manifestation', 'n'), ('sta...
#
#                                              lemmatized  \
# 5931  ['kid', 'go', 'leadership', 'camp', 'come', 'w...
# 470   ['suspect', 'late', 'u', 'theatre', 'attack', ...
# 874                    ['@loboparanoico', 'mad', 'men']
# 6352  ['slum', 'manifestation', 'state', 'failure', ...
#
#                                               lemma_str  \
# 5931  kid go leadership camp come work today ask bat...
# 470   suspect late u theatre attack psychological issue
# 874                              @loboparanoico mad men
# 6352  slum manifestation state failure provide housi...
#
#                                      filtered_lemma_str  \
# 5931  kid leadership camp come work today ask bathro...
# 470     suspect late theatre attack psychological issue
# 874                              @loboparanoico mad men
# 6352  slum manifestation state failure provide housi...
#
#                                            combined_str
# 5931  kid leadership camp come work today ask bathro...
# 470   suspect late theatre attack psychological issu...
# 874                        @loboparanoico mad men blood
# 6352  slum manifestation state failure provide housi...

# %%
train = train.
# Out:
#    id                                       combined_str
# 0   0                          happen terrible car crash
# 1   2  heard #earthquake different city stay safe eve...
# 2   3  forest fire spot pond geese flee across street...
# 3   9               apocalypse light #spokane #wildfires
# 4  11                 typhoon soudelor kill china taiwan

# %%
# Setting target variables, creating combined data and saving index for dividing combined data later.
labels = train['target'].values
idx = len(labels)
combined = pd.concat([train, test])
combined = combined.text.values
